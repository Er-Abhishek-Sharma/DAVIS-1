# %%
import pandas as pd

# %%
# creating a list to store marks of five students
marks = 90, 98, 80, 70, 79


# subjects corresponding to the marks
subject = "Hindi", "English", "Math", "Science", "SST"

table = pd.Series(data = marks, index = sujectb)
print(table)
# Out:
# Hindi      90
# English    98
# Math       80
# Science    70
# SST        79
# dtype: int64

# %%
data = {'stdid' : ['std101', 'std102', 'std103', 'std104', 'std105'],
        'stdname' :['Shubham', 'Abhi', 'Aadi', 'Chetan', 'Abhay'],
        'rollNo.' : ['1', '2', '3', '4', '5'],
        'standard' : ['1th', '2nd', '3rd', '4th', '5th']
       }
df = pd.DataFrame(data)
print(df)
# Out:
#     stdid  stdname rollNo. standard
# 0  std101  Shubham       1      1th
# 1  std102     Abhi       2      2nd
# 2  std103     Aadi       3      3rd
# 3  std104   Chetan       4      4th
# 4  std105    Abhay       5      5th
